# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Using-paramiko,-pandas-and-a-VM-class" data-toc-modified-id="Using-paramiko,-pandas-and-a-VM-class-1">Using paramiko, pandas and a VM class</a></span><ul class="toc-item"><li><span><a href="#Package-Imports" data-toc-modified-id="Package-Imports-1.1">Package Imports</a></span></li><li><span><a href="#Constants" data-toc-modified-id="Constants-1.2">Constants</a></span></li><li><span><a href="#Creating-1-VM-Class" data-toc-modified-id="Creating-1-VM-Class-1.3">Creating 1 VM Class</a></span></li><li><span><a href="#DataFrame-of-Classes" data-toc-modified-id="DataFrame-of-Classes-1.4">DataFrame of Classes</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Using paramiko, pandas and a VM class
# This notebook accompanies this medium blog post where I provide background and methodology.

# %% [markdown]
# ## Package Imports

# %%
#Data Science Stack
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

#virtualmachine.py python script
from virtualmachine import VM, clean_columns

#pandas notebook display formatting 
pd.options.display.max_columns = 100
pd.options.display.max_rows = 100

# %% [markdown]
# ## Constants

# %%
HOST = '35.204.7.190'
USERNAME = 'louwjlabuschagne_gmail_com'
PUB_KEY = '/Users/louwrenslabuschagne/.ssh/id_rsa.pub'

# %% [markdown]
# ## Creating 1 VM Class

# %%
vm = VM(HOST, USERNAME, PUB_KEY)

# %%
print(vm)
# Out:
# louwjlabuschagne_gmail_com@35.204.7.190 ✅

# %% [markdown]
# The default command for the `parse_key_value_output()` function is `lscpu`, but any colon separated bash output will be parsed into a DataFrame.

# %%
vm_lscpu = vm.parse_key_value_output('lscpu').T.head(10)
vm_lscpu.to_csv('../table_outputs/vm_lscpu.csv')
vm_lscpu
# Out:
#                             0
# ARCHITECTURE           x86_64
# CPUOPMODES      32-bit,64-bit
# BYTEORDER        LittleEndian
# CPUS                        1
# ONLINECPUSLIST              0
# THREADSPERCORE              1
# CORESPERSOCKET              1
# SOCKETS                     1
# NUMANODES                   1
# VENDORID         GenuineIntel

# %% [markdown]
# Like the `cat /proc/meminfo` command.

# %%
vm_meminfo = vm.parse_key_value_output('cat /proc/meminfo').T.head(10)
vm_meminfo.to_csv('../table_outputs/vm_meminfo.csv')
vm_meminfo
# Out:
#                       0
# MEMTOTAL      1020416kB
# MEMFREE        869804kB
# MEMAVAILABLE   832908kB
# BUFFERS          9104kB
# CACHED          53076kB
# SWAPCACHED          0kB
# ACTIVE          90008kB
# INACTIVE        19704kB
# ACTIVEANON      47680kB
# INACTIVEANON     4060kB

# %% [markdown]
# I advice making predefined functions for bash command who's output isn't alway as straight forward, but which you'll use a lot.

# %%
vm_df = vm.cmd_df()
vm_df.to_csv('../table_outputs/vm1_df.csv', index=False)
vm_df
# Out:
#   FILESYSTEM  1KBLOCKS     USED AVAILABLE  USE_percentage_      MOUNTED_ON
# 0       udev    499068        0    499068             0.00            /dev
# 1      tmpfs    102044     4212     97832             0.05            /run
# 2  /dev/sda1  10253588  1092372   8620648             0.12               /
# 3      tmpfs    510208        0    510208             0.00        /dev/shm
# 4      tmpfs      5120        0      5120             0.00       /run/lock
# 5      tmpfs    510208        0    510208             0.00  /sys/fs/cgroup

# %% [markdown]
# Below we see this VM has a total of 44.96 Tb of storage available.

# %%
print('%.2f Kb total storage'%(vm.cmd_df().AVAILABLE.astype(int).sum()/1e3))
# Out:
# 10243.08 Kb total storage

# %% [markdown]
# Or any other command you can think of.

# %%
vm.exec_command('which python')
# Out:
# ['/usr/bin/python']

# %% [markdown]
# Literally...

# %%
vm.exec_command('ls --help')[0:20]
# Out:
# ['Usage: ls [OPTION]... [FILE]...',
#  'List information about the FILEs (the current directory by default).',
#  'Sort entries alphabetically if none of -cftuvSUX nor --sort is specified.',
#  '',
#  'Mandatory arguments to long options are mandatory for short options too.',
#  '  -a, --all                  do not ignore entries starting with .',
#  '  -A, --almost-all           do not list implied . and ..',
#  '      --author               with -l, print the author of each file',
#  '  -b, --escape               print C-style escapes for nongraphic characters',
#  '      --block-size=SIZE      scale sizes by SIZE before printing them; e.g.,',
#  "                               '--block-size=M' prints sizes in units of",
#  '                               1,048,576 bytes; see SIZE format below',
#  '  -B, --ignore-backups       do not list implied entries ending with ~',
#  '  -c                         with -lt: sort by, and show, ctime (time of last',
#  '                               modification of file status information);',
#  '                               with -l: show ctime and sort by name;',
#  '                               otherwise: sort by ctime, newest first',
#  '  -C                         list entries by columns',
#  "      --color[=WHEN]         colorize the output; WHEN can be 'always' (default",
#  "                               if omitted), 'auto', or 'never'; more info below"]

# %% [markdown]
# ## DataFrame of Classes

# %% [markdown]
# Now... The magic begins when we merge the nice abilities of `DataFrame`'s with our VM Class.
#
#
# First we create a `DataFrame` with all our VMs.

# %%
ips = ['35.204.7.190',
'35.204.197.82',
'35.204.4.10',
'35.204.193.154']

VMs = pd.DataFrame(dict(IP=ips))
VMs
# Out:
#                IP
# 0    35.204.7.190
# 1   35.204.197.82
# 2     35.204.4.10
# 3  35.204.193.154

# %% [markdown]
# Then we create a VM Class to store in the VM column in the VMs DataFrame

# %%
VMs['VM'] = VMs.apply(lambda row: VM(row.IP, USERNAME, PUB_KEY), axis=1)
VMs
# Out:
#                IP                                           VM
# 0    35.204.7.190    louwjlabuschagne_gmail_com@35.204.7.190 ✅
# 1   35.204.197.82   louwjlabuschagne_gmail_com@35.204.197.82 ✅
# 2     35.204.4.10     louwjlabuschagne_gmail_com@35.204.4.10 ✅
# 3  35.204.193.154  louwjlabuschagne_gmail_com@35.204.193.154 ✅

# %%
VMs.to_csv('../table_outputs/VM_connected_state.csv', index=False)

# %% [markdown]
# Now we can do some amazing things like getting the memory capabilities for all these machines.

# %%
lscpu = VMs.VM.apply(lambda vm: vm.parse_key_value_output('lscpu'))
lscpu
# Out:
# 0      ARCHITECTURE     CPUOPMODES     BYTEORDER CP...
# 1      ARCHITECTURE     CPUOPMODES     BYTEORDER CP...
# 2      ARCHITECTURE     CPUOPMODES     BYTEORDER CP...
# 3      ARCHITECTURE     CPUOPMODES     BYTEORDER CP...
# Name: VM, dtype: object

# %% [markdown]
# We just need a little helper function to convert our series of dataframes to a dataframe - this is an undesired artifact of using apply. Any suggestions welcome.

# %%
def series_to_df(series):
    df = pd.DataFrame()
    for d in series:
        df = pd.concat([df, d], axis=0, sort=True)
    df.reset_index(inplace=True, drop=True)
    return(df)

# %%
series_to_df(lscpu)
# Out:
#   ARCHITECTURE BOGOMIPS     BYTEORDER CORESPERSOCKET CPUFAMILY    CPUMHZ  \
# 0       x86_64  4000.37  LittleEndian              1         6  2000.186
# 1       x86_64  4000.37  LittleEndian              1         6  2000.186
# 2       x86_64  4000.36  LittleEndian              1         6  2000.184
# 3       x86_64  4000.36  LittleEndian              1         6  2000.184
#
#       CPUOPMODES CPUS                                              FLAGS  \
# 0  32-bit,64-bit    1  fpuvmedepsetscmsrpaemcecx8apicsepmtrrpgemcacmo...
# 1  32-bit,64-bit    2  fpuvmedepsetscmsrpaemcecx8apicsepmtrrpgemcacmo...
# 2  32-bit,64-bit    1  fpuvmedepsetscmsrpaemcecx8apicsepmtrrpgemcacmo...
# 3  32-bit,64-bit    2  fpuvmedepsetscmsrpaemcecx8apicsepmtrrpgemcacmo...
#
#   HYPERVISORVENDOR L1DCACHE L1ICACHE L2CACHE L3CACHE MODEL  \
# 0              KVM      32K      32K    256K  56320K    85
# 1              KVM      32K      32K    256K  56320K    85
# 2              KVM      32K      32K    256K  56320K    85
# 3              KVM      32K      32K    256K  56320K    85
#
#                     MODELNAME NUMANODE0CPUS NUMANODES ONLINECPUSLIST SOCKETS  \
# 0  Intel(R)Xeon(R)CPU@2.00GHz             0         1              0       1
# 1  Intel(R)Xeon(R)CPU@2.00GHz           0,1         1            0,1       1
# 2  Intel(R)Xeon(R)CPU@2.00GHz             0         1              0       1
# 3  Intel(R)Xeon(R)CPU@2.00GHz           0,1         1            0,1       1
#
#   STEPPING THREADSPERCORE      VENDORID VIRTUALIZATIONTYPE
# 0        3              1  GenuineIntel               full
# 1        3              2  GenuineIntel               full
# 2        3              1  GenuineIntel               full
# 3        3              2  GenuineIntel               full

# %% [markdown]
# Now we can merge it back with our VMs DataFrame.

# %%
VMs = pd.concat([VMs, series_to_df(lscpu)], axis=1)
VMs
# Out:
#                IP                                           VM ARCHITECTURE  \
# 0    35.204.7.190    louwjlabuschagne_gmail_com@35.204.7.190 ✅       x86_64
# 1   35.204.197.82   louwjlabuschagne_gmail_com@35.204.197.82 ✅       x86_64
# 2     35.204.4.10     louwjlabuschagne_gmail_com@35.204.4.10 ✅       x86_64
# 3  35.204.193.154  louwjlabuschagne_gmail_com@35.204.193.154 ✅       x86_64
#
#   BOGOMIPS     BYTEORDER CORESPERSOCKET CPUFAMILY    CPUMHZ     CPUOPMODES  \
# 0  4000.37  LittleEndian              1         6  2000.186  32-bit,64-bit
# 1  4000.37  LittleEndian              1         6  2000.186  32-bit,64-bit
# 2  4000.36  LittleEndian              1         6  2000.184  32-bit,64-bit
# 3  4000.36  LittleEndian              1         6  2000.184  32-bit,64-bit
#
#   CPUS                                              FLAGS HYPERVISORVENDOR  \
# 0    1  fpuvmedepsetscmsrpaemcecx8apicsepmtrrpgemcacmo...              KVM
# 1    2  fpuvmedepsetscmsrpaemcecx8apicsepmtrrpgemcacmo...              KVM
# 2    1  fpuvmedepsetscmsrpaemcecx8apicsepmtrrpgemcacmo...              KVM
# 3    2  fpuvmedepsetscmsrpaemcecx8apicsepmtrrpgemcacmo...              KVM
#
#   L1DCACHE L1ICACHE L2CACHE L3CACHE MODEL                   MODELNAME  \
# 0      32K      32K    256K  56320K    85  Intel(R)Xeon(R)CPU@2.00GHz
# 1      32K      32K    256K  56320K    85  Intel(R)Xeon(R)CPU@2.00GHz
# 2      32K      32K    256K  56320K    85  Intel(R)Xeon(R)CPU@2.00GHz
# 3      32K      32K    256K  56320K    85  Intel(R)Xeon(R)CPU@2.00GHz
#
#   NUMANODE0CPUS NUMANODES ONLINECPUSLIST SOCKETS STEPPING THREADSPERCORE  \
# 0             0         1              0       1        3              1
# 1           0,1         1            0,1       1        3              2
# 2             0         1              0       1        3              1
# 3           0,1         1            0,1       1        3              2
#
#        VENDORID VIRTUALIZATIONTYPE
# 0  GenuineIntel               full
# 1  GenuineIntel               full
# 2  GenuineIntel               full
# 3  GenuineIntel               full

# %%
VMs.drop('FLAGS', axis=1).T.to_csv('../table_outputs/VMs_lscpu.csv')

# %% [markdown]
# An voila, we've got a `DataFrame` with our VM data populated. Another interesting command to use would be `lscpu`. This time we call `series_to_df` directly on the output series of DataFrames from `apply()`

# %%
meminfo = series_to_df(VMs.VM.apply(lambda vm: vm.parse_key_value_output('cat /proc/meminfo')))

meminfo

# %% [markdown]
# Concatenate the DataFrames again.

# %%
VMs = pd.concat([VMs, meminfo], axis=1)

# %%
VMs
# Out:
#                IP                                           VM   ACTIVE  \
# 0    35.204.7.190    louwjlabuschagne_gmail_com@35.204.7.190 ✅  90520kB
# 1   35.204.197.82   louwjlabuschagne_gmail_com@35.204.197.82 ✅  91228kB
# 2     35.204.4.10     louwjlabuschagne_gmail_com@35.204.4.10 ✅  89964kB
# 3  35.204.193.154  louwjlabuschagne_gmail_com@35.204.193.154 ✅  90576kB
#
#   ACTIVEANON ACTIVEFILE ANONHUGEPAGES ANONPAGES BOUNCE BUFFERS   CACHED  \
# 0    47692kB    42828kB           0kB   47564kB    0kB  9136kB  53356kB
# 1    47804kB    43424kB           0kB   47648kB    0kB  9144kB  53096kB
# 2    47692kB    42272kB           0kB   47568kB    0kB  9096kB  53012kB
# 3    47976kB    42600kB           0kB   47836kB    0kB  9088kB  53100kB
#
#   COMMITLIMIT COMMITTED_AS DIRECTMAP1G DIRECTMAP2M DIRECTMAP4K DIRTY  \
# 0    510208kB     122912kB         0kB   1003520kB     45044kB  32kB
# 1   1026232kB     113492kB         0kB   2052096kB     45044kB   8kB
# 2    510208kB     122944kB         0kB   1005568kB     42996kB  12kB
# 3   1026232kB     113444kB         0kB   2052096kB     45044kB  12kB
#
#   HARDWARECORRUPTED HUGEPAGESIZE HUGEPAGES_FREE HUGEPAGES_RSVD HUGEPAGES_SURP  \
# 0               0kB       2048kB              0              0              0
# 1               0kB       2048kB              0              0              0
# 2               0kB       2048kB              0              0              0
# 3               0kB       2048kB              0              0              0
#
#   HUGEPAGES_TOTAL INACTIVE INACTIVEANON INACTIVEFILE KERNELSTACK   MAPPED  \
# 0               0  19516kB       4060kB      15456kB      1164kB  25484kB
# 1               0  18664kB       4132kB      14532kB      1280kB  25028kB
# 2               0  19688kB       4060kB      15628kB      1164kB  25584kB
# 3               0  19436kB       4132kB      15304kB      1328kB  25708kB
#
#   MEMAVAILABLE    MEMFREE   MEMTOTAL MLOCKED NFS_UNSTABLE PAGETABLES   SHMEM  \
# 0     833352kB   870088kB  1020416kB     0kB          0kB     2964kB  4212kB
# 1    1850344kB  1891216kB  2052468kB     0kB          0kB     2936kB  4288kB
# 2     832880kB   869824kB  1020416kB     0kB          0kB     2948kB  4212kB
# 3    1849908kB  1890804kB  2052468kB     0kB          0kB     2976kB  4288kB
#
#   SHMEMHUGEPAGES SHMEMPMDMAPPED     SLAB SRECLAIMABLE SUNRECLAIM SWAPCACHED  \
# 0            0kB            0kB  19924kB      11052kB     8872kB        0kB
# 1            0kB            0kB  21372kB      11176kB    10196kB        0kB
# 2            0kB            0kB  19944kB      11020kB     8924kB        0kB
# 3            0kB            0kB  21496kB      11180kB    10316kB        0kB
#
#   SWAPFREE SWAPTOTAL UNEVICTABLE VMALLOCCHUNK   VMALLOCTOTAL VMALLOCUSED  \
# 0      0kB       0kB         0kB          0kB  34359738367kB         0kB
# 1      0kB       0kB         0kB          0kB  34359738367kB         0kB
# 2      0kB       0kB         0kB          0kB  34359738367kB         0kB
# 3      0kB       0kB         0kB          0kB  34359738367kB         0kB
#
#   WRITEBACK WRITEBACKTMP ARCHITECTURE BOGOMIPS     BYTEORDER CORESPERSOCKET  \
# 0       0kB          0kB       x86_64  4000.37  LittleEndian              1
# 1       0kB          0kB       x86_64  4000.37  LittleEndian              1
# 2       0kB          0kB       x86_64  4000.36  LittleEndian              1
# 3       0kB          0kB       x86_64  4000.36  LittleEndian              1
#
#   CPUFAMILY    CPUMHZ     CPUOPMODES CPUS  \
# 0         6  2000.186  32-bit,64-bit    1
# 1         6  2000.186  32-bit,64-bit    2
# 2         6  2000.184  32-bit,64-bit    1
# 3         6  2000.184  32-bit,64-bit    2
#
#                                                FLAGS HYPERVISORVENDOR  \
# 0  fpuvmedepsetscmsrpaemcecx8apicsepmtrrpgemcacmo...              KVM
# 1  fpuvmedepsetscmsrpaemcecx8apicsepmtrrpgemcacmo...              KVM
# 2  fpuvmedepsetscmsrpaemcecx8apicsepmtrrpgemcacmo...              KVM
# 3  fpuvmedepsetscmsrpaemcecx8apicsepmtrrpgemcacmo...              KVM
#
#   L1DCACHE L1ICACHE L2CACHE L3CACHE MODEL                   MODELNAME  \
# 0      32K      32K    256K  56320K    85  Intel(R)Xeon(R)CPU@2.00GHz
# 1      32K      32K    256K  56320K    85  Intel(R)Xeon(R)CPU@2.00GHz
# 2      32K      32K    256K  56320K    85  Intel(R)Xeon(R)CPU@2.00GHz
# 3      32K      32K    256K  56320K    85  Intel(R)Xeon(R)CPU@2.00GHz
#
#   NUMANODE0CPUS NUMANODES ONLINECPUSLIST SOCKETS STEPPING THREADSPERCORE  \
# 0             0         1              0       1        3              1
# 1           0,1         1            0,1       1        3              2
# 2             0         1              0       1        3              1
# 3           0,1         1            0,1       1        3              2
#
#        VENDORID VIRTUALIZATIONTYPE
# 0  GenuineIntel               full
# 1  GenuineIntel               full
# 2  GenuineIntel               full
# 3  GenuineIntel               full

# %%
df_2_save = VMs.rename(columns={'ip':'IP'})[['IP', 'ACTIVE', 'MEMAVAILABLE', 'MEMFREE', 'MEMTOTAL',
                            'CPUFAMILY', 'CPUMHZ', 'CPUOPMODES', 'CPUS', 'HYPERVISORVENDOR',
                            'VENDORID','HYPERVISORVENDOR', 'MODEL', 'MODELNAME', 'NUMANODE0CPUS', 
                             'NUMANODES', 'ONLINECPUSLIST','SOCKETS', 'STEPPING', 'THREADSPERCORE', 'VENDORID',
                             'VIRTUALIZATIONTYPE']].T
df_2_save.to_csv('../table_outputs/VMs_info.csv')
df_2_save
# Out:
#                                              0                           1  \
# IP                                35.204.7.190               35.204.197.82
# ACTIVE                                 90520kB                     91228kB
# MEMAVAILABLE                          833352kB                   1850344kB
# MEMFREE                               870088kB                   1891216kB
# MEMTOTAL                             1020416kB                   2052468kB
# CPUFAMILY                                    6                           6
# CPUMHZ                                2000.186                    2000.186
# CPUOPMODES                       32-bit,64-bit               32-bit,64-bit
# CPUS                                         1                           2
# HYPERVISORVENDOR                           KVM                         KVM
# VENDORID                          GenuineIntel                GenuineIntel
# HYPERVISORVENDOR                           KVM                         KVM
# MODEL                                       85                          85
# MODELNAME           Intel(R)Xeon(R)CPU@2.00GHz  Intel(R)Xeon(R)CPU@2.00GHz
# NUMANODE0CPUS                                0                         0,1
# NUMANODES                                    1                           1
# ONLINECPUSLIST                               0                         0,1
# SOCKETS                                      1                           1
# STEPPING                                     3                           3
# THREADSPERCORE                               1                           2
# VENDORID                          GenuineIntel                GenuineIntel
# VIRTUALIZATIONTYPE                        full                        full
#
#                                              2                           3
# IP                                 35.204.4.10              35.204.193.154
# ACTIVE                                 89964kB                     90576kB
# MEMAVAILABLE                          832880kB                   1849908kB
# MEMFREE                               869824kB                   1890804kB
# MEMTOTAL                             1020416kB                   2052468kB
# CPUFAMILY                                    6                           6
# CPUMHZ                                2000.184                    2000.184
# CPUOPMODES                       32-bit,64-bit               32-bit,64-bit
# CPUS                                         1                           2
# HYPERVISORVENDOR                           KVM                         KVM
# VENDORID                          GenuineIntel                GenuineIntel
# HYPERVISORVENDOR                           KVM                         KVM
# MODEL                                       85                          85
# MODELNAME           Intel(R)Xeon(R)CPU@2.00GHz  Intel(R)Xeon(R)CPU@2.00GHz
# NUMANODE0CPUS                                0                         0,1
# NUMANODES                                    1                           1
# ONLINECPUSLIST                               0                         0,1
# SOCKETS                                      1                           1
# STEPPING                                     3                           3
# THREADSPERCORE                               1                           2
# VENDORID                          GenuineIntel                GenuineIntel
# VIRTUALIZATIONTYPE                        full                        full
